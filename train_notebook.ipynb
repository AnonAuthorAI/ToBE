# %%
import numpy as np
import torch
from args import parse_args
from graphimb import *
from data_utils import (
    get_data_stat,
    get_natural_imbalanced_split_data,
    get_step_imbalanced_split_data,
    load_data, 
)
from tobe import TopoBalanceAugmenter
from trainer import NodeClassificationTrainer
from utils import get_model, get_device, print_centered

# %% [markdown]
# # Running Experiment
#
# This script will run experiments on all the combinations of following settings (specified by the global variables below):
#
# | Setting         | (Default) Values                           | Description                                                        |
# | --------------- | ------------------------------------------ | ------------------------------------------------------------------ |
# | `DATASET_SPACE` | `['cora', 'citeseer', 'pubmed']`           | The datasets to use.                                               |
# | `IMB_TYPES`     | `{'step': [10, 20], 'natural': [50, 100]}` | The imbalance types and ratios.                                    |
# | `TOBE_MODES`    | `['dummy', 'pred', 'topo']`                | The ToBE modes to test, `dummy` means no topological augmentation. |
#
# For other settings, we use the default values specified in `config.yaml`.

# %%
""" Experiment Setup """

import sys
sys.argv = [""]
args = parse_args()

DATASET_SPACE = ["cora", "citeseer", "pubmed"]
MODE_SPACE = ["dummy", "pred", "topo"]
IMB_SPACE = {
    'step': [10, 20],
    'natural': [50, 100],
}

# %%
args.gpu_id = 1

device = get_device(args.gpu_id)

print(
    f"Run experiment with\n"
    f"  - Datasets:        {DATASET_SPACE}\n"
    f"  - ToBE modes:      {MODE_SPACE}\n"
    f"  - Imbalance types: {IMB_SPACE}\n"
)

print_centered("Arguments", 40, fillchar="=")
kwlen = max([len(k) for k in args.__dict__.keys()]) + 1
for keys, values in args.__dict__.items():
    print(f"{keys:{kwlen}}: {values}")
print_centered("", 40, fillchar="=")

# run the experiment

for imb_type in IMB_SPACE.keys():  # loop over imbalance types
    
    for imb_ratio in IMB_SPACE[imb_type]: # loop over imbalance ratios
    
        print_centered(f"Imbalance Type [{imb_type.title()}] - Ratio [{imb_ratio}]", 80, fillchar="/", prefix="\n")
        
        for dataset in DATASET_SPACE:  # loop over datasets

            print_centered(f"Dataset [{dataset.title()}]", 80, fillchar="=", prefix="\n")

            args.imb_type = imb_type
            args.imb_ratio = imb_ratio
            args.dataset = dataset
            
            for tobe_mode in MODE_SPACE:    # loop over ToBE modes
                
                print_centered(f"Dataset [{args.dataset.title()}] - {args.imb_type.title()}IR [{args.imb_ratio}] - ToBE [{tobe_mode}]", 80, fillchar="=")

                best_results = []
                for i_run in range(1, args.n_runs + 1):
                    seed = args.seed + i_run

                    # load imbalanced data
                    data = load_data(args.dataset, to_device=device, verbose=args.debug)
                    if args.imb_type == "step":
                        data = get_step_imbalanced_split_data(
                            data, imbratio=args.imb_ratio, random_seed=seed, verbose=args.debug
                        )
                    elif args.imb_type == "natural":
                        data = get_natural_imbalanced_split_data(
                            data, imbratio=args.imb_ratio, random_seed=seed, verbose=args.debug
                        )
                    else:
                        raise ValueError(
                            f"imb_type must be one of ['step', 'natural'], got {args.imb_type}."
                        )
                    data = get_data_stat(data, store_in_data=True, verbose=args.debug)

                    # initialize model
                    model = get_model(
                        gnn_arch=args.gnn_arch,
                        feat_dim=data.n_feat,
                        hid_dim=args.hid_dim,
                        out_dim=data.n_class,
                        n_layer=args.n_layer,
                        device=device,
                    )
                    # tobe augmenter
                    augmenter = TopoBalanceAugmenter(mode=tobe_mode, random_state=seed)
                    # trainer
                    trainer = NodeClassificationTrainer(
                        model=model,
                        data=data,
                        device=device,
                        augmenter=augmenter,  # ToBE augmentation, to disable, set augmenter=None
                        learning_rate=args.lr,
                        weight_decay=args.weight_decay,
                        train_epoch=args.epochs,
                        early_stop_patience=args.early_stop,
                        eval_freq=1,
                        verbose_freq=None,
                        enable_tqdm=args.tqdm,
                        random_state=seed,
                    )
                    # train the GNN with ToBE augmentation
                    best_model = trainer.train()
                    # print best results
                    trainer.print_best_results()
                    # save best results
                    best_results.append(trainer.best_eval_results)

                # print the average performance of the best model
                info = f"Avg Test Performance ({args.n_runs} runs): "
                for metric in trainer.eval_metrics.keys():
                    scores = np.array(
                        [
                            best_results[i][metric]["test"] * 100
                            for i in range(len(best_results))
                        ]
                    )
                    info += f" | {metric.upper()}: {scores.mean():.2f} ± {scores.std()/(len(scores)**0.5):.2f}"
                print(info)
# Out:
# Now using GPU #1: Tesla V100-SXM2-32GB
# Run experiment with
#   - Datasets:        ['cora', 'citeseer', 'pubmed']
#   - ToBE modes:      ['dummy', 'pred', 'topo']
#   - Imbalance types: {'step': [10, 20], 'natural': [50, 100]}
#
# ============== Arguments ==============
# gpu_id       : 1
# seed         : 42
# n_runs       : 5
# debug        : False
# dataset      : cora
# imb_type     : step
# imb_ratio    : 10
# gnn_arch     : GCN
# n_layer      : 3
# hid_dim      : 256
# lr           : 0.01
# weight_decay : 0.0005
# epochs       : 2000
# early_stop   : 200
# tqdm         : False
# tobe_mode    : all
# ========================================
#
# ////////////////////// Imbalance Type [Step] - Ratio [10] //////////////////////
#
# ================================ Dataset [Cora] ================================
# ================= Dataset [Cora] - StepIR [10] - ToBE [dummy] =================
# Best Epoch:   97 | train/val/test | BACC: 100.0/61.93/60.55 | MACRO-F1: 100.0/59.65/59.29 | node/edge ratio: 100.00/100.00%
# Best Epoch:  122 | train/val/test | BACC: 100.0/59.97/59.05 | MACRO-F1: 100.0/57.31/56.80 | node/edge ratio: 100.00/100.00%
# Best Epoch:  132 | train/val/test | BACC: 100.0/63.83/62.47 | MACRO-F1: 100.0/62.23/60.79 | node/edge ratio: 100.00/100.00%
# Best Epoch:   60 | train/val/test | BACC: 100.0/61.60/60.74 | MACRO-F1: 100.0/58.04/59.09 | node/edge ratio: 100.00/100.00%
# Best Epoch:  151 | train/val/test | BACC: 100.0/57.82/55.99 | MACRO-F1: 100.0/53.30/51.88 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 59.76 ± 0.97 | MACRO-F1: 57.57 ± 1.39
# ================== Dataset [Cora] - StepIR [10] - ToBE [pred] ==================
# Best Epoch:  426 | train/val/test | BACC: 100.0/65.17/63.70 | MACRO-F1: 100.0/63.00/61.99 | node/edge ratio: 100.26/102.97%
# Best Epoch:  161 | train/val/test | BACC: 100.0/71.84/68.77 | MACRO-F1: 100.0/71.09/67.79 | node/edge ratio: 100.26/103.21%
# Best Epoch:  124 | train/val/test | BACC: 100.0/69.54/67.93 | MACRO-F1: 100.0/69.26/67.69 | node/edge ratio: 100.26/103.03%
# Best Epoch:  483 | train/val/test | BACC: 100.0/67.12/66.02 | MACRO-F1: 100.0/64.77/64.28 | node/edge ratio: 100.26/103.22%
# Best Epoch:   90 | train/val/test | BACC: 100.0/61.18/59.96 | MACRO-F1: 100.0/58.85/58.07 | node/edge ratio: 100.26/103.26%
# Avg Test Performance (5 runs):  | BACC: 65.27 ± 1.42 | MACRO-F1: 63.96 ± 1.64
# ================== Dataset [Cora] - StepIR [10] - ToBE [topo] ==================
# Best Epoch:  110 | train/val/test | BACC: 100.0/69.97/69.09 | MACRO-F1: 100.0/66.37/66.16 | node/edge ratio: 100.26/101.43%
# Best Epoch:  153 | train/val/test | BACC: 100.0/72.13/68.82 | MACRO-F1: 100.0/68.22/66.15 | node/edge ratio: 100.26/101.68%
# Best Epoch:  117 | train/val/test | BACC: 100.0/75.62/73.93 | MACRO-F1: 100.0/71.35/70.81 | node/edge ratio: 100.26/101.54%
# Best Epoch:   71 | train/val/test | BACC: 100.0/69.50/67.75 | MACRO-F1: 100.0/68.11/66.80 | node/edge ratio: 100.26/101.54%
# Best Epoch:   77 | train/val/test | BACC: 100.0/78.03/77.92 | MACRO-F1: 100.0/75.06/76.42 | node/edge ratio: 100.26/101.60%
# Avg Test Performance (5 runs):  | BACC: 71.50 ± 1.72 | MACRO-F1: 69.27 ± 1.78
#
# ============================== Dataset [Citeseer] ==============================
# =============== Dataset [Citeseer] - StepIR [10] - ToBE [dummy] ===============
# Best Epoch:   57 | train/val/test | BACC: 100.0/42.27/41.85 | MACRO-F1: 100.0/33.57/32.96 | node/edge ratio: 100.00/100.00%
# Best Epoch:  211 | train/val/test | BACC: 100.0/46.49/44.47 | MACRO-F1: 100.0/39.83/37.62 | node/edge ratio: 100.00/100.00%
# Best Epoch:   85 | train/val/test | BACC: 100.0/35.72/36.41 | MACRO-F1: 100.0/28.07/27.64 | node/edge ratio: 100.00/100.00%
# Best Epoch:   66 | train/val/test | BACC: 100.0/36.54/36.79 | MACRO-F1: 100.0/28.47/26.82 | node/edge ratio: 100.00/100.00%
# Best Epoch:  171 | train/val/test | BACC: 100.0/34.90/32.80 | MACRO-F1: 100.0/22.77/21.23 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 38.46 ± 1.86 | MACRO-F1: 29.26 ± 2.50
# ================ Dataset [Citeseer] - StepIR [10] - ToBE [pred] ================
# Best Epoch:  204 | train/val/test | BACC: 100.0/60.94/60.41 | MACRO-F1: 100.0/58.48/59.51 | node/edge ratio: 100.18/103.74%
# Best Epoch:  312 | train/val/test | BACC: 100.0/48.81/46.51 | MACRO-F1: 100.0/45.09/43.27 | node/edge ratio: 100.18/103.17%
# Best Epoch:  317 | train/val/test | BACC: 100.0/58.92/60.26 | MACRO-F1: 100.0/57.94/59.61 | node/edge ratio: 100.18/103.82%
# Best Epoch:  114 | train/val/test | BACC: 100.0/47.96/40.25 | MACRO-F1: 100.0/43.50/37.73 | node/edge ratio: 100.18/103.75%
# Best Epoch:  162 | train/val/test | BACC: 100.0/59.74/56.42 | MACRO-F1: 100.0/58.82/55.75 | node/edge ratio: 100.18/103.86%
# Avg Test Performance (5 runs):  | BACC: 52.77 ± 3.60 | MACRO-F1: 51.17 ± 4.02
# ================ Dataset [Citeseer] - StepIR [10] - ToBE [topo] ================
# Best Epoch:  265 | train/val/test | BACC: 100.0/59.83/59.55 | MACRO-F1: 100.0/58.04/59.09 | node/edge ratio: 100.18/100.94%
# Best Epoch:   84 | train/val/test | BACC: 100.0/52.21/50.15 | MACRO-F1: 100.0/48.13/46.26 | node/edge ratio: 100.18/100.84%
# Best Epoch:  130 | train/val/test | BACC: 100.0/61.34/61.63 | MACRO-F1: 100.0/59.70/60.94 | node/edge ratio: 100.18/100.94%
# Best Epoch:  110 | train/val/test | BACC: 100.0/60.11/60.14 | MACRO-F1: 100.0/59.09/59.37 | node/edge ratio: 100.18/100.91%
# Best Epoch:  263 | train/val/test | BACC: 99.17/50.58/50.54 | MACRO-F1: 99.17/43.60/43.63 | node/edge ratio: 100.18/101.40%
# Avg Test Performance (5 runs):  | BACC: 56.40 ± 2.23 | MACRO-F1: 53.86 ± 3.29
#
# =============================== Dataset [Pubmed] ===============================
# ================ Dataset [Pubmed] - StepIR [10] - ToBE [dummy] ================
# Best Epoch:   60 | train/val/test | BACC: 100.0/64.17/61.63 | MACRO-F1: 100.0/50.42/48.98 | node/edge ratio: 100.00/100.00%
# Best Epoch:   67 | train/val/test | BACC: 100.0/71.01/69.15 | MACRO-F1: 100.0/64.89/64.67 | node/edge ratio: 100.00/100.00%
# Best Epoch:  100 | train/val/test | BACC: 100.0/66.70/64.53 | MACRO-F1: 100.0/55.09/53.49 | node/edge ratio: 100.00/100.00%
# Best Epoch:   95 | train/val/test | BACC: 100.0/75.37/69.35 | MACRO-F1: 100.0/68.57/61.28 | node/edge ratio: 100.00/100.00%
# Best Epoch:  291 | train/val/test | BACC: 100.0/63.73/60.01 | MACRO-F1: 100.0/48.47/45.26 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 64.93 ± 1.70 | MACRO-F1: 54.74 ± 3.26
# ================= Dataset [Pubmed] - StepIR [10] - ToBE [pred] =================
# Best Epoch:  164 | train/val/test | BACC: 100.0/71.47/69.60 | MACRO-F1: 100.0/68.97/67.15 | node/edge ratio: 100.02/103.28%
# Best Epoch:  143 | train/val/test | BACC: 98.33/75.48/69.83 | MACRO-F1: 92.48/75.00/69.86 | node/edge ratio: 100.02/103.02%
# Best Epoch:  107 | train/val/test | BACC: 100.0/75.46/69.16 | MACRO-F1: 100.0/74.59/68.10 | node/edge ratio: 100.02/103.07%
# Best Epoch:  204 | train/val/test | BACC: 100.0/74.82/69.25 | MACRO-F1: 100.0/72.07/66.16 | node/edge ratio: 100.02/103.00%
# Best Epoch:   76 | train/val/test | BACC: 100.0/69.49/65.68 | MACRO-F1: 100.0/65.12/60.14 | node/edge ratio: 100.02/103.18%
# Avg Test Performance (5 runs):  | BACC: 68.71 ± 0.68 | MACRO-F1: 66.28 ± 1.48
# ================= Dataset [Pubmed] - StepIR [10] - ToBE [topo] =================
# Best Epoch:  115 | train/val/test | BACC: 100.0/64.79/62.53 | MACRO-F1: 100.0/53.94/53.24 | node/edge ratio: 100.02/101.29%
# Best Epoch:   67 | train/val/test | BACC: 100.0/68.40/64.78 | MACRO-F1: 100.0/60.52/57.16 | node/edge ratio: 100.02/101.52%
# Best Epoch:   53 | train/val/test | BACC: 100.0/69.61/69.20 | MACRO-F1: 100.0/63.15/63.46 | node/edge ratio: 100.02/101.44%
# Best Epoch:  105 | train/val/test | BACC: 100.0/78.82/73.51 | MACRO-F1: 100.0/77.92/72.77 | node/edge ratio: 100.02/101.36%
# Best Epoch:  276 | train/val/test | BACC: 100.0/72.29/68.50 | MACRO-F1: 100.0/65.84/60.50 | node/edge ratio: 100.02/101.47%
# Avg Test Performance (5 runs):  | BACC: 67.70 ± 1.70 | MACRO-F1: 61.43 ± 2.96
#
# ////////////////////// Imbalance Type [Step] - Ratio [20] //////////////////////
#
# ================================ Dataset [Cora] ================================
# ================= Dataset [Cora] - StepIR [20] - ToBE [dummy] =================
# Best Epoch:  109 | train/val/test | BACC: 100.0/59.18/57.26 | MACRO-F1: 100.0/54.00/53.17 | node/edge ratio: 100.00/100.00%
# Best Epoch:   92 | train/val/test | BACC: 100.0/55.59/54.02 | MACRO-F1: 100.0/49.15/47.81 | node/edge ratio: 100.00/100.00%
# Best Epoch:  193 | train/val/test | BACC: 100.0/62.16/59.82 | MACRO-F1: 100.0/59.74/57.35 | node/edge ratio: 100.00/100.00%
# Best Epoch:   89 | train/val/test | BACC: 100.0/53.72/52.78 | MACRO-F1: 100.0/47.01/47.33 | node/edge ratio: 100.00/100.00%
# Best Epoch:   89 | train/val/test | BACC: 100.0/53.54/51.65 | MACRO-F1: 100.0/47.07/44.61 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 55.11 ± 1.35 | MACRO-F1: 50.05 ± 2.05
# ================== Dataset [Cora] - StepIR [20] - ToBE [pred] ==================
# Best Epoch:  118 | train/val/test | BACC: 100.0/66.41/65.15 | MACRO-F1: 100.0/65.42/64.47 | node/edge ratio: 100.26/102.96%
# Best Epoch:  187 | train/val/test | BACC: 100.0/61.29/59.58 | MACRO-F1: 100.0/58.24/58.00 | node/edge ratio: 100.26/103.14%
# Best Epoch:  294 | train/val/test | BACC: 100.0/71.49/70.50 | MACRO-F1: 100.0/68.82/68.67 | node/edge ratio: 100.26/102.82%
# Best Epoch:  165 | train/val/test | BACC: 100.0/65.46/64.18 | MACRO-F1: 100.0/62.53/61.92 | node/edge ratio: 100.26/103.13%
# Best Epoch:  300 | train/val/test | BACC: 100.0/54.89/54.05 | MACRO-F1: 100.0/52.12/51.89 | node/edge ratio: 100.26/103.49%
# Avg Test Performance (5 runs):  | BACC: 62.69 ± 2.48 | MACRO-F1: 60.99 ± 2.56
# ================== Dataset [Cora] - StepIR [20] - ToBE [topo] ==================
# Best Epoch:  254 | train/val/test | BACC: 100.0/67.86/66.08 | MACRO-F1: 100.0/65.33/64.14 | node/edge ratio: 100.26/101.44%
# Best Epoch:  153 | train/val/test | BACC: 100.0/75.05/74.71 | MACRO-F1: 100.0/71.60/72.61 | node/edge ratio: 100.26/101.62%
# Best Epoch:  164 | train/val/test | BACC: 100.0/74.54/72.44 | MACRO-F1: 100.0/71.58/70.76 | node/edge ratio: 100.26/101.68%
# Best Epoch:  316 | train/val/test | BACC: 100.0/67.40/66.49 | MACRO-F1: 100.0/64.76/64.65 | node/edge ratio: 100.26/101.62%
# Best Epoch:   94 | train/val/test | BACC: 100.0/63.67/61.72 | MACRO-F1: 100.0/58.09/57.33 | node/edge ratio: 100.26/101.61%
# Avg Test Performance (5 runs):  | BACC: 68.29 ± 2.09 | MACRO-F1: 65.90 ± 2.42
#
# ============================== Dataset [Citeseer] ==============================
# =============== Dataset [Citeseer] - StepIR [20] - ToBE [dummy] ===============
# Best Epoch:  146 | train/val/test | BACC: 100.0/35.57/34.08 | MACRO-F1: 100.0/25.16/23.58 | node/edge ratio: 100.00/100.00%
# Best Epoch:  188 | train/val/test | BACC: 100.0/37.44/35.35 | MACRO-F1: 100.0/29.69/26.51 | node/edge ratio: 100.00/100.00%
# Best Epoch:  145 | train/val/test | BACC: 100.0/33.93/32.20 | MACRO-F1: 100.0/22.69/20.89 | node/edge ratio: 100.00/100.00%
# Best Epoch:   14 | train/val/test | BACC: 46.67/35.14/34.59 | MACRO-F1: 45.51/21.72/21.35 | node/edge ratio: 100.00/100.00%
# Best Epoch:   16 | train/val/test | BACC: 46.67/34.95/35.07 | MACRO-F1: 45.50/22.01/21.49 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 34.26 ± 0.50 | MACRO-F1: 22.76 ± 0.93
# ================ Dataset [Citeseer] - StepIR [20] - ToBE [pred] ================
# Best Epoch:  262 | train/val/test | BACC: 100.0/59.66/58.41 | MACRO-F1: 100.0/59.41/58.56 | node/edge ratio: 100.18/104.58%
# Best Epoch:  223 | train/val/test | BACC: 100.0/48.23/47.34 | MACRO-F1: 100.0/45.73/44.89 | node/edge ratio: 100.18/104.51%
# Best Epoch:  138 | train/val/test | BACC: 100.0/57.76/54.23 | MACRO-F1: 100.0/55.71/52.76 | node/edge ratio: 100.18/104.84%
# Best Epoch:  295 | train/val/test | BACC: 100.0/45.64/40.76 | MACRO-F1: 100.0/42.63/37.92 | node/edge ratio: 100.18/104.13%
# Best Epoch:  171 | train/val/test | BACC: 100.0/48.12/46.97 | MACRO-F1: 100.0/45.20/44.57 | node/edge ratio: 100.18/104.17%
# Avg Test Performance (5 runs):  | BACC: 49.54 ± 2.75 | MACRO-F1: 47.74 ± 3.21
# ================ Dataset [Citeseer] - StepIR [20] - ToBE [topo] ================
# Best Epoch:  121 | train/val/test | BACC: 100.0/60.13/59.02 | MACRO-F1: 100.0/59.45/58.80 | node/edge ratio: 100.18/101.15%
# Best Epoch:  104 | train/val/test | BACC: 100.0/48.64/51.14 | MACRO-F1: 100.0/46.74/48.28 | node/edge ratio: 100.18/101.26%
# Best Epoch:  300 | train/val/test | BACC: 100.0/51.89/53.65 | MACRO-F1: 100.0/50.49/52.94 | node/edge ratio: 100.18/101.07%
# Best Epoch:  240 | train/val/test | BACC: 100.0/58.47/56.59 | MACRO-F1: 100.0/57.81/56.47 | node/edge ratio: 100.18/100.89%
# Best Epoch:  132 | train/val/test | BACC: 100.0/45.89/45.47 | MACRO-F1: 100.0/33.73/33.64 | node/edge ratio: 100.18/101.36%
# Avg Test Performance (5 runs):  | BACC: 53.18 ± 2.09 | MACRO-F1: 50.03 ± 3.99
#
# =============================== Dataset [Pubmed] ===============================
# ================ Dataset [Pubmed] - StepIR [20] - ToBE [dummy] ================
# Best Epoch:   99 | train/val/test | BACC: 100.0/62.88/59.69 | MACRO-F1: 100.0/48.95/46.62 | node/edge ratio: 100.00/100.00%
# Best Epoch:  123 | train/val/test | BACC: 100.0/66.61/62.69 | MACRO-F1: 100.0/55.53/52.91 | node/edge ratio: 100.00/100.00%
# Best Epoch:  147 | train/val/test | BACC: 100.0/64.69/61.75 | MACRO-F1: 100.0/50.67/48.59 | node/edge ratio: 100.00/100.00%
# Best Epoch:  196 | train/val/test | BACC: 100.0/64.05/60.62 | MACRO-F1: 100.0/48.82/45.61 | node/edge ratio: 100.00/100.00%
# Best Epoch:  214 | train/val/test | BACC: 100.0/63.75/60.38 | MACRO-F1: 100.0/48.04/45.23 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 61.03 ± 0.48 | MACRO-F1: 47.79 ± 1.26
# ================= Dataset [Pubmed] - StepIR [20] - ToBE [pred] =================
# Best Epoch:  221 | train/val/test | BACC: 100.0/68.80/67.35 | MACRO-F1: 100.0/66.81/66.17 | node/edge ratio: 100.02/103.46%
# Best Epoch:  281 | train/val/test | BACC: 100.0/67.80/64.77 | MACRO-F1: 100.0/66.11/63.99 | node/edge ratio: 100.02/103.50%
# Best Epoch:  231 | train/val/test | BACC: 100.0/67.88/65.30 | MACRO-F1: 100.0/64.45/61.80 | node/edge ratio: 100.02/103.72%
# Best Epoch:  205 | train/val/test | BACC: 100.0/66.86/60.71 | MACRO-F1: 100.0/62.87/56.11 | node/edge ratio: 100.02/103.40%
# Best Epoch:  130 | train/val/test | BACC: 100.0/69.19/65.81 | MACRO-F1: 100.0/66.70/63.53 | node/edge ratio: 100.02/103.65%
# Avg Test Performance (5 runs):  | BACC: 64.79 ± 0.99 | MACRO-F1: 62.32 ± 1.52
# ================= Dataset [Pubmed] - StepIR [20] - ToBE [topo] =================
# Best Epoch:   65 | train/val/test | BACC: 98.33/70.03/70.11 | MACRO-F1: 88.03/69.53/69.89 | node/edge ratio: 100.02/101.17%
# Best Epoch:   77 | train/val/test | BACC: 98.33/67.88/64.30 | MACRO-F1: 88.03/65.26/62.82 | node/edge ratio: 100.02/101.34%
# Best Epoch:   78 | train/val/test | BACC: 100.0/71.30/69.76 | MACRO-F1: 100.0/65.25/64.41 | node/edge ratio: 100.02/101.39%
# Best Epoch:  202 | train/val/test | BACC: 100.0/74.54/70.48 | MACRO-F1: 100.0/70.69/66.01 | node/edge ratio: 100.02/101.44%
# Best Epoch:   62 | train/val/test | BACC: 100.0/63.32/60.03 | MACRO-F1: 100.0/48.01/44.48 | node/edge ratio: 100.02/101.09%
# Avg Test Performance (5 runs):  | BACC: 66.93 ± 1.85 | MACRO-F1: 61.52 ± 3.95
#
# //////////////////// Imbalance Type [Natural] - Ratio [50] ////////////////////
#
# ================================ Dataset [Cora] ================================
# ================ Dataset [Cora] - NaturalIR [50] - ToBE [dummy] ================
# Best Epoch:  179 | train/val/test | BACC: 100.0/58.59/55.43 | MACRO-F1: 100.0/56.60/52.78 | node/edge ratio: 100.00/100.00%
# Best Epoch:  276 | train/val/test | BACC: 100.0/70.30/69.45 | MACRO-F1: 100.0/70.13/69.71 | node/edge ratio: 100.00/100.00%
# Best Epoch:   68 | train/val/test | BACC: 85.71/50.84/49.64 | MACRO-F1: 80.95/48.90/47.29 | node/edge ratio: 100.00/100.00%
# Best Epoch:  267 | train/val/test | BACC: 100.0/62.22/63.93 | MACRO-F1: 100.0/61.98/63.80 | node/edge ratio: 100.00/100.00%
# Best Epoch:  119 | train/val/test | BACC: 100.0/60.33/62.38 | MACRO-F1: 100.0/59.48/60.70 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 60.17 ± 3.09 | MACRO-F1: 58.86 ± 3.56
# ================ Dataset [Cora] - NaturalIR [50] - ToBE [pred] ================
# Best Epoch:  239 | train/val/test | BACC: 100.0/68.96/67.32 | MACRO-F1: 100.0/68.76/67.01 | node/edge ratio: 100.26/101.68%
# Best Epoch:  179 | train/val/test | BACC: 100.0/65.39/62.81 | MACRO-F1: 100.0/63.99/61.88 | node/edge ratio: 100.26/101.47%
# Best Epoch:  171 | train/val/test | BACC: 99.45/61.38/60.96 | MACRO-F1: 99.58/59.72/59.67 | node/edge ratio: 100.26/101.85%
# Best Epoch:  181 | train/val/test | BACC: 99.71/68.40/69.97 | MACRO-F1: 99.59/67.41/68.61 | node/edge ratio: 100.26/101.76%
# Best Epoch:  375 | train/val/test | BACC: 100.0/72.58/71.41 | MACRO-F1: 100.0/72.49/71.70 | node/edge ratio: 100.26/101.61%
# Avg Test Performance (5 runs):  | BACC: 66.49 ± 1.80 | MACRO-F1: 65.77 ± 1.97
# ================ Dataset [Cora] - NaturalIR [50] - ToBE [topo] ================
# Best Epoch:  104 | train/val/test | BACC: 100.0/64.72/63.49 | MACRO-F1: 100.0/61.62/60.45 | node/edge ratio: 100.26/101.09%
# Best Epoch:  187 | train/val/test | BACC: 100.0/71.54/69.15 | MACRO-F1: 100.0/70.43/68.73 | node/edge ratio: 100.26/100.78%
# Best Epoch:  107 | train/val/test | BACC: 99.45/59.31/59.83 | MACRO-F1: 99.58/55.43/56.22 | node/edge ratio: 100.26/101.32%
# Best Epoch:  528 | train/val/test | BACC: 100.0/69.77/68.58 | MACRO-F1: 100.0/67.43/65.46 | node/edge ratio: 100.26/101.09%
# Best Epoch:  121 | train/val/test | BACC: 100.0/66.90/65.74 | MACRO-F1: 100.0/63.85/62.71 | node/edge ratio: 100.26/100.98%
# Avg Test Performance (5 runs):  | BACC: 65.36 ± 1.54 | MACRO-F1: 62.71 ± 1.91
#
# ============================== Dataset [Citeseer] ==============================
# ============== Dataset [Citeseer] - NaturalIR [50] - ToBE [dummy] ==============
# Best Epoch:   90 | train/val/test | BACC: 83.33/48.05/49.31 | MACRO-F1: 81.48/40.93/42.39 | node/edge ratio: 100.00/100.00%
# Best Epoch:  202 | train/val/test | BACC: 100.0/51.72/50.41 | MACRO-F1: 100.0/46.49/45.45 | node/edge ratio: 100.00/100.00%
# Best Epoch:  165 | train/val/test | BACC: 100.0/46.28/45.00 | MACRO-F1: 100.0/39.12/37.93 | node/edge ratio: 100.00/100.00%
# Best Epoch:  175 | train/val/test | BACC: 100.0/46.81/48.28 | MACRO-F1: 100.0/40.47/42.41 | node/edge ratio: 100.00/100.00%
# Best Epoch:  146 | train/val/test | BACC: 100.0/42.20/42.61 | MACRO-F1: 100.0/32.24/32.50 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 47.12 ± 1.29 | MACRO-F1: 40.14 ± 2.02
# ============== Dataset [Citeseer] - NaturalIR [50] - ToBE [pred] ==============
# Best Epoch:  209 | train/val/test | BACC: 100.0/55.69/52.59 | MACRO-F1: 100.0/54.93/52.27 | node/edge ratio: 100.18/101.82%
# Best Epoch:  333 | train/val/test | BACC: 100.0/49.84/47.50 | MACRO-F1: 100.0/49.25/46.73 | node/edge ratio: 100.18/101.64%
# Best Epoch:  235 | train/val/test | BACC: 100.0/54.17/53.73 | MACRO-F1: 100.0/53.28/52.84 | node/edge ratio: 100.18/102.20%
# Best Epoch:  148 | train/val/test | BACC: 100.0/52.88/52.85 | MACRO-F1: 100.0/51.57/51.92 | node/edge ratio: 100.18/101.82%
# Best Epoch:  264 | train/val/test | BACC: 100.0/53.46/53.58 | MACRO-F1: 100.0/53.31/53.35 | node/edge ratio: 100.18/101.89%
# Avg Test Performance (5 runs):  | BACC: 52.05 ± 1.04 | MACRO-F1: 51.42 ± 1.07
# ============== Dataset [Citeseer] - NaturalIR [50] - ToBE [topo] ==============
# Best Epoch:  125 | train/val/test | BACC: 100.0/61.04/59.02 | MACRO-F1: 100.0/60.26/58.01 | node/edge ratio: 100.18/100.43%
# Best Epoch:  263 | train/val/test | BACC: 100.0/53.39/50.59 | MACRO-F1: 100.0/52.30/49.49 | node/edge ratio: 100.18/100.47%
# Best Epoch:  126 | train/val/test | BACC: 100.0/60.06/60.31 | MACRO-F1: 100.0/58.12/58.61 | node/edge ratio: 100.18/100.52%
# Best Epoch:  180 | train/val/test | BACC: 100.0/55.43/54.29 | MACRO-F1: 100.0/54.45/53.02 | node/edge ratio: 100.18/100.53%
# Best Epoch:  158 | train/val/test | BACC: 100.0/61.75/61.23 | MACRO-F1: 100.0/59.65/58.70 | node/edge ratio: 100.18/100.52%
# Avg Test Performance (5 runs):  | BACC: 57.09 ± 1.80 | MACRO-F1: 55.57 ± 1.65
#
# =============================== Dataset [Pubmed] ===============================
# =============== Dataset [Pubmed] - NaturalIR [50] - ToBE [dummy] ===============
# Best Epoch:  177 | train/val/test | BACC: 100.0/51.85/51.50 | MACRO-F1: 100.0/46.40/46.06 | node/edge ratio: 100.00/100.00%
# Best Epoch:  193 | train/val/test | BACC: 100.0/49.06/49.98 | MACRO-F1: 100.0/44.83/45.80 | node/edge ratio: 100.00/100.00%
# Best Epoch:  170 | train/val/test | BACC: 100.0/47.51/47.66 | MACRO-F1: 100.0/44.44/44.57 | node/edge ratio: 100.00/100.00%
# Best Epoch:   85 | train/val/test | BACC: 65.33/55.62/55.56 | MACRO-F1: 60.10/49.24/49.20 | node/edge ratio: 100.00/100.00%
# Best Epoch:  188 | train/val/test | BACC: 100.0/53.11/53.01 | MACRO-F1: 100.0/47.67/47.61 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 51.54 ± 1.20 | MACRO-F1: 46.65 ± 0.72
# =============== Dataset [Pubmed] - NaturalIR [50] - ToBE [pred] ===============
# Best Epoch:  183 | train/val/test | BACC: 100.0/55.03/54.73 | MACRO-F1: 100.0/53.34/53.12 | node/edge ratio: 100.02/102.24%
# Best Epoch:  165 | train/val/test | BACC: 100.0/40.85/41.38 | MACRO-F1: 100.0/34.31/34.90 | node/edge ratio: 100.02/101.39%
# Best Epoch:  143 | train/val/test | BACC: 100.0/56.35/56.35 | MACRO-F1: 100.0/56.41/56.38 | node/edge ratio: 100.02/102.03%
# Best Epoch:  169 | train/val/test | BACC: 98.00/58.99/58.77 | MACRO-F1: 93.09/56.41/56.13 | node/edge ratio: 100.02/101.87%
# Best Epoch:  116 | train/val/test | BACC: 66.67/54.98/54.83 | MACRO-F1: 66.34/48.61/48.48 | node/edge ratio: 100.02/102.26%
# Avg Test Performance (5 runs):  | BACC: 53.21 ± 2.73 | MACRO-F1: 49.80 ± 3.57
# =============== Dataset [Pubmed] - NaturalIR [50] - ToBE [topo] ===============
# Best Epoch:  162 | train/val/test | BACC: 99.33/55.58/55.72 | MACRO-F1: 88.55/51.84/51.99 | node/edge ratio: 100.02/100.61%
# Best Epoch:  114 | train/val/test | BACC: 100.0/40.52/41.07 | MACRO-F1: 100.0/33.82/34.51 | node/edge ratio: 100.02/100.28%
# Best Epoch:  179 | train/val/test | BACC: 100.0/59.29/59.20 | MACRO-F1: 100.0/60.24/60.16 | node/edge ratio: 100.02/100.53%
# Best Epoch:  215 | train/val/test | BACC: 98.00/57.25/56.92 | MACRO-F1: 93.09/52.09/51.59 | node/edge ratio: 100.02/100.56%
# Best Epoch:  355 | train/val/test | BACC: 100.0/69.71/69.66 | MACRO-F1: 100.0/71.13/71.12 | node/edge ratio: 100.02/100.95%
# Avg Test Performance (5 runs):  | BACC: 56.51 ± 4.09 | MACRO-F1: 53.87 ± 5.37
#
# //////////////////// Imbalance Type [Natural] - Ratio [100] ////////////////////
#
# ================================ Dataset [Cora] ================================
# =============== Dataset [Cora] - NaturalIR [100] - ToBE [dummy] ===============
# Best Epoch:  101 | train/val/test | BACC: 85.71/61.94/60.90 | MACRO-F1: 84.13/60.55/59.84 | node/edge ratio: 100.00/100.00%
# Best Epoch:  245 | train/val/test | BACC: 100.0/70.65/66.22 | MACRO-F1: 100.0/70.47/66.60 | node/edge ratio: 100.00/100.00%
# Best Epoch:  177 | train/val/test | BACC: 99.69/50.73/50.52 | MACRO-F1: 99.77/48.05/47.63 | node/edge ratio: 100.00/100.00%
# Best Epoch:  246 | train/val/test | BACC: 99.69/58.30/59.41 | MACRO-F1: 99.77/57.31/58.63 | node/edge ratio: 100.00/100.00%
# Best Epoch:  239 | train/val/test | BACC: 100.0/63.43/63.64 | MACRO-F1: 100.0/65.79/64.74 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 60.14 ± 2.39 | MACRO-F1: 59.49 ± 2.96
# ================ Dataset [Cora] - NaturalIR [100] - ToBE [pred] ================
# Best Epoch:  344 | train/val/test | BACC: 100.0/67.49/66.67 | MACRO-F1: 100.0/66.80/66.70 | node/edge ratio: 100.26/101.72%
# Best Epoch:  353 | train/val/test | BACC: 100.0/70.37/65.86 | MACRO-F1: 100.0/69.31/65.28 | node/edge ratio: 100.26/101.44%
# Best Epoch:  171 | train/val/test | BACC: 99.38/62.70/61.55 | MACRO-F1: 98.93/62.22/60.62 | node/edge ratio: 100.26/102.20%
# Best Epoch:  131 | train/val/test | BACC: 99.01/63.08/63.15 | MACRO-F1: 99.35/61.57/61.77 | node/edge ratio: 100.26/101.78%
# Best Epoch:  605 | train/val/test | BACC: 100.0/69.06/70.64 | MACRO-F1: 100.0/69.02/70.47 | node/edge ratio: 100.26/101.80%
# Avg Test Performance (5 runs):  | BACC: 65.58 ± 1.40 | MACRO-F1: 64.97 ± 1.58
# ================ Dataset [Cora] - NaturalIR [100] - ToBE [topo] ================
# Best Epoch:  200 | train/val/test | BACC: 100.0/67.82/65.78 | MACRO-F1: 100.0/65.53/63.38 | node/edge ratio: 100.26/101.24%
# Best Epoch:  386 | train/val/test | BACC: 100.0/74.23/70.42 | MACRO-F1: 100.0/73.61/70.37 | node/edge ratio: 100.26/100.86%
# Best Epoch:  235 | train/val/test | BACC: 99.86/66.20/64.91 | MACRO-F1: 98.34/66.17/64.74 | node/edge ratio: 100.26/101.43%
# Best Epoch:  389 | train/val/test | BACC: 99.69/63.81/63.89 | MACRO-F1: 99.77/62.16/61.89 | node/edge ratio: 100.26/101.10%
# Best Epoch:  343 | train/val/test | BACC: 100.0/74.17/74.86 | MACRO-F1: 100.0/75.02/76.04 | node/edge ratio: 100.26/101.23%
# Avg Test Performance (5 runs):  | BACC: 67.97 ± 1.84 | MACRO-F1: 67.28 ± 2.34
#
# ============================== Dataset [Citeseer] ==============================
# ============= Dataset [Citeseer] - NaturalIR [100] - ToBE [dummy] =============
# Best Epoch:  274 | train/val/test | BACC: 99.83/45.22/46.09 | MACRO-F1: 99.71/37.54/38.84 | node/edge ratio: 100.00/100.00%
# Best Epoch:  188 | train/val/test | BACC: 91.33/46.90/46.66 | MACRO-F1: 93.02/42.05/41.45 | node/edge ratio: 100.00/100.00%
# Best Epoch:  239 | train/val/test | BACC: 100.0/44.96/44.27 | MACRO-F1: 100.0/38.65/37.56 | node/edge ratio: 100.00/100.00%
# Best Epoch:  186 | train/val/test | BACC: 83.00/46.06/47.16 | MACRO-F1: 79.41/38.94/39.92 | node/edge ratio: 100.00/100.00%
# Best Epoch:   85 | train/val/test | BACC: 66.50/42.53/42.25 | MACRO-F1: 63.91/33.68/32.85 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 45.29 ± 0.81 | MACRO-F1: 38.12 ± 1.31
# ============== Dataset [Citeseer] - NaturalIR [100] - ToBE [pred] ==============
# Best Epoch:  689 | train/val/test | BACC: 83.33/54.30/53.33 | MACRO-F1: 80.00/53.17/52.51 | node/edge ratio: 100.18/101.88%
# Best Epoch:  303 | train/val/test | BACC: 99.83/49.74/50.81 | MACRO-F1: 99.71/47.56/48.64 | node/edge ratio: 100.18/103.01%
# Best Epoch:  384 | train/val/test | BACC: 100.0/55.59/54.98 | MACRO-F1: 100.0/54.45/53.67 | node/edge ratio: 100.18/102.58%
# Best Epoch:  328 | train/val/test | BACC: 100.0/55.17/53.12 | MACRO-F1: 100.0/54.19/51.66 | node/edge ratio: 100.18/102.32%
# Best Epoch:  220 | train/val/test | BACC: 83.17/57.24/56.73 | MACRO-F1: 82.96/54.70/54.01 | node/edge ratio: 100.18/103.37%
# Avg Test Performance (5 runs):  | BACC: 53.79 ± 0.89 | MACRO-F1: 52.10 ± 0.86
# ============== Dataset [Citeseer] - NaturalIR [100] - ToBE [topo] ==============
# Best Epoch:  768 | train/val/test | BACC: 100.0/58.44/59.82 | MACRO-F1: 100.0/55.77/58.05 | node/edge ratio: 100.18/100.43%
# Best Epoch:  465 | train/val/test | BACC: 99.83/56.87/57.41 | MACRO-F1: 99.71/56.00/56.61 | node/edge ratio: 100.18/100.73%
# Best Epoch:  237 | train/val/test | BACC: 100.0/54.48/54.16 | MACRO-F1: 100.0/51.60/51.55 | node/edge ratio: 100.18/100.57%
# Best Epoch:  345 | train/val/test | BACC: 99.57/60.67/61.39 | MACRO-F1: 99.70/58.97/59.79 | node/edge ratio: 100.18/100.59%
# Best Epoch:  274 | train/val/test | BACC: 83.17/51.67/52.69 | MACRO-F1: 82.96/45.60/46.70 | node/edge ratio: 100.18/100.74%
# Avg Test Performance (5 runs):  | BACC: 57.09 ± 1.47 | MACRO-F1: 54.54 ± 2.14
#
# =============================== Dataset [Pubmed] ===============================
# ============== Dataset [Pubmed] - NaturalIR [100] - ToBE [dummy] ==============
# Best Epoch:  167 | train/val/test | BACC: 66.67/53.42/53.53 | MACRO-F1: 65.08/47.06/47.19 | node/edge ratio: 100.00/100.00%
# Best Epoch:  161 | train/val/test | BACC: 100.0/45.23/46.28 | MACRO-F1: 100.0/38.92/40.00 | node/edge ratio: 100.00/100.00%
# Best Epoch:   88 | train/val/test | BACC: 66.67/48.35/48.26 | MACRO-F1: 65.08/42.04/41.97 | node/edge ratio: 100.00/100.00%
# Best Epoch:   95 | train/val/test | BACC: 66.67/51.23/51.28 | MACRO-F1: 65.08/45.35/45.38 | node/edge ratio: 100.00/100.00%
# Best Epoch:  102 | train/val/test | BACC: 66.67/51.96/51.58 | MACRO-F1: 65.08/46.06/45.71 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 50.19 ± 1.15 | MACRO-F1: 44.05 ± 1.18
# =============== Dataset [Pubmed] - NaturalIR [100] - ToBE [pred] ===============
# Best Epoch:  100 | train/val/test | BACC: 65.67/56.78/56.67 | MACRO-F1: 60.60/50.25/50.16 | node/edge ratio: 100.02/102.45%
# Best Epoch:  102 | train/val/test | BACC: 66.00/49.44/50.27 | MACRO-F1: 61.98/43.19/43.97 | node/edge ratio: 100.02/101.91%
# Best Epoch:  272 | train/val/test | BACC: 66.33/56.90/57.32 | MACRO-F1: 63.47/50.39/50.74 | node/edge ratio: 100.02/102.36%
# Best Epoch:   93 | train/val/test | BACC: 66.67/49.27/49.32 | MACRO-F1: 65.08/43.56/43.58 | node/edge ratio: 100.02/102.21%
# Best Epoch:   94 | train/val/test | BACC: 65.67/55.11/55.18 | MACRO-F1: 60.60/48.77/48.85 | node/edge ratio: 100.02/102.22%
# Avg Test Performance (5 runs):  | BACC: 53.75 ± 1.48 | MACRO-F1: 47.46 ± 1.37
# =============== Dataset [Pubmed] - NaturalIR [100] - ToBE [topo] ===============
# Best Epoch:  166 | train/val/test | BACC: 98.67/56.81/56.75 | MACRO-F1: 93.76/50.93/50.81 | node/edge ratio: 100.02/100.83%
# Best Epoch:  161 | train/val/test | BACC: 100.0/44.86/45.25 | MACRO-F1: 100.0/39.76/40.14 | node/edge ratio: 100.02/100.34%
# Best Epoch:  222 | train/val/test | BACC: 99.33/58.95/59.30 | MACRO-F1: 96.63/54.85/55.23 | node/edge ratio: 100.02/100.54%
# Best Epoch:   89 | train/val/test | BACC: 61.67/55.62/55.23 | MACRO-F1: 49.15/48.99/48.66 | node/edge ratio: 100.02/100.56%
# Best Epoch:  142 | train/val/test | BACC: 65.67/55.96/55.63 | MACRO-F1: 61.65/49.43/49.14 | node/edge ratio: 100.02/100.77%
# Avg Test Performance (5 runs):  | BACC: 54.43 ± 2.15 | MACRO-F1: 48.79 ± 2.20
