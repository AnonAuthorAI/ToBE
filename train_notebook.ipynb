# %%
import numpy as np
import torch
from args import parse_args
from graphimb import *
from data_utils import (
    get_data_stat,
    get_natural_imbalanced_split_data,
    get_step_imbalanced_split_data,
    load_data, 
)
from tobe import TopoBalanceAugmenter
from trainer import NodeClassificationTrainer
from utils import get_model, get_device, print_centered

# %% [markdown]
# # Running Experiment
#
# This script will run experiments on all the combinations of following settings (specified by the global variables below):
#
# | Setting         | (Default) Values                           | Description                                                        |
# | --------------- | ------------------------------------------ | ------------------------------------------------------------------ |
# | `DATASET_SPACE` | `['cora', 'citeseer', 'pubmed']`           | The datasets to use.                                               |
# | `IMB_TYPES`     | `{'step': [10, 20], 'natural': [50, 100]}` | The imbalance types and ratios.                                    |
# | `TOBE_MODES`    | `['dummy', 'tobe0', 'tobe1']`                | The ToBE modes to test, `dummy` means no topological augmentation. |
#
# For other settings, we use the default values specified in `config.yaml`.

# %%
""" Experiment Setup """

import sys
sys.argv = [""]
args = parse_args()

DATASET_SPACE = ["cora", "citeseer", "pubmed"]
MODE_SPACE = ["dummy", "tobe0", "tobe1"]
IMB_SPACE = {
    'step': [10, 20],
    'natural': [50, 100],
}

# %%
device = get_device(args.gpu_id)

print(
    f"Run experiment with\n"
    f"  - Datasets:        {DATASET_SPACE}\n"
    f"  - ToBE modes:      {MODE_SPACE}\n"
    f"  - Imbalance types: {IMB_SPACE}\n"
)

print_centered("Arguments", 40, fillchar="=")
kwlen = max([len(k) for k in args.__dict__.keys()]) + 1
for keys, values in args.__dict__.items():
    print(f"{keys:{kwlen}}: {values}")
print_centered("", 40, fillchar="=")

# run the experiment

for imb_type in IMB_SPACE.keys():  # loop over imbalance types
    
    for imb_ratio in IMB_SPACE[imb_type]: # loop over imbalance ratios
    
        print_centered(f"Imbalance Type [{imb_type.title()}] - Ratio [{imb_ratio}]", 80, fillchar="/", prefix="\n")
        
        for dataset in DATASET_SPACE:  # loop over datasets

            print_centered(f"Dataset [{dataset.title()}]", 80, fillchar="=", prefix="\n")

            args.imb_type = imb_type
            args.imb_ratio = imb_ratio
            args.dataset = dataset
            
            for tobe_mode in MODE_SPACE:    # loop over ToBE modes
                
                print_centered(f"Dataset [{args.dataset.title()}] - {args.imb_type.title()}IR [{args.imb_ratio}] - ToBE [{tobe_mode}]", 80, fillchar="=")

                best_results = []
                for i_run in range(1, args.n_runs + 1):
                    seed = args.seed + i_run

                    # load imbalanced data
                    data = load_data(args.dataset, to_device=device, verbose=args.debug)
                    if args.imb_type == "step":
                        data = get_step_imbalanced_split_data(
                            data, imbratio=args.imb_ratio, random_seed=seed, verbose=args.debug
                        )
                    elif args.imb_type == "natural":
                        data = get_natural_imbalanced_split_data(
                            data, imbratio=args.imb_ratio, random_seed=seed, verbose=args.debug
                        )
                    else:
                        raise ValueError(
                            f"imb_type must be one of ['step', 'natural'], got {args.imb_type}."
                        )
                    data = get_data_stat(data, store_in_data=True, verbose=args.debug)

                    # initialize model
                    model = get_model(
                        gnn_arch=args.gnn_arch,
                        feat_dim=data.n_feat,
                        hid_dim=args.hid_dim,
                        out_dim=data.n_class,
                        n_layer=args.n_layer,
                        device=device,
                    )
                    # tobe augmenter
                    augmenter = TopoBalanceAugmenter(mode=tobe_mode, random_state=seed)
                    # trainer
                    trainer = NodeClassificationTrainer(
                        model=model,
                        data=data,
                        device=device,
                        augmenter=augmenter,  # ToBE augmentation, to disable, set augmenter=None
                        learning_rate=args.lr,
                        weight_decay=args.weight_decay,
                        train_epoch=args.epochs,
                        early_stop_patience=args.early_stop,
                        eval_freq=1,
                        verbose_freq=None,
                        enable_tqdm=args.tqdm,
                        random_state=seed,
                    )
                    # train the GNN with ToBE augmentation
                    best_model = trainer.train()
                    # print best results
                    trainer.print_best_results()
                    # save best results
                    best_results.append(trainer.best_eval_results)

                # print the average performance of the best model
                info = f"Avg Test Performance ({args.n_runs} runs): "
                for metric in trainer.eval_metrics.keys():
                    scores = np.array(
                        [
                            best_results[i][metric]["test"] * 100
                            for i in range(len(best_results))
                        ]
                    )
                    info += f" | {metric.upper()}: {scores.mean():.2f} ± {scores.std()/(len(scores)**0.5):.2f}"
                print(info)
# Out:
# Now using GPU #0: Tesla V100-SXM2-32GB
# Run experiment with
#   - Datasets:        ['cora', 'citeseer', 'pubmed']
#   - ToBE modes:      ['dummy', 'tobe0', 'tobe1']
#   - Imbalance types: {'step': [10, 20], 'natural': [50, 100]}
#
# ============== Arguments ==============
# gpu_id       : 0
# seed         : 42
# n_runs       : 5
# debug        : False
# dataset      : cora
# imb_type     : step
# imb_ratio    : 10
# gnn_arch     : GCN
# n_layer      : 3
# hid_dim      : 256
# lr           : 0.01
# weight_decay : 0.0005
# epochs       : 2000
# early_stop   : 200
# tqdm         : False
# tobe_mode    : all
# ========================================
#
# ////////////////////// Imbalance Type [Step] - Ratio [10] //////////////////////
#
# ================================ Dataset [Cora] ================================
# ================= Dataset [Cora] - StepIR [10] - ToBE [dummy] =================
# Best Epoch:   97 | train/val/test | BACC: 100.0/61.93/60.55 | MACRO-F1: 100.0/59.65/59.29 | node/edge ratio: 100.00/100.00%
# Best Epoch:  122 | train/val/test | BACC: 100.0/59.97/59.05 | MACRO-F1: 100.0/57.31/56.80 | node/edge ratio: 100.00/100.00%
# Best Epoch:  132 | train/val/test | BACC: 100.0/63.83/62.47 | MACRO-F1: 100.0/62.23/60.79 | node/edge ratio: 100.00/100.00%
# Best Epoch:   60 | train/val/test | BACC: 100.0/61.60/60.74 | MACRO-F1: 100.0/58.04/59.09 | node/edge ratio: 100.00/100.00%
# Best Epoch:  151 | train/val/test | BACC: 100.0/57.82/55.99 | MACRO-F1: 100.0/53.30/51.88 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 59.76 ± 0.97 | MACRO-F1: 57.57 ± 1.39
# ================= Dataset [Cora] - StepIR [10] - ToBE [tobe0] =================
# Best Epoch:  293 | train/val/test | BACC: 100.0/65.03/64.81 | MACRO-F1: 100.0/62.73/63.07 | node/edge ratio: 100.26/103.01%
# Best Epoch:  102 | train/val/test | BACC: 100.0/71.42/68.39 | MACRO-F1: 100.0/68.27/66.31 | node/edge ratio: 100.26/103.26%
# Best Epoch:  124 | train/val/test | BACC: 100.0/69.54/67.93 | MACRO-F1: 100.0/69.26/67.69 | node/edge ratio: 100.26/102.91%
# Best Epoch:  239 | train/val/test | BACC: 100.0/66.39/64.88 | MACRO-F1: 100.0/64.07/63.67 | node/edge ratio: 100.26/103.16%
# Best Epoch:  124 | train/val/test | BACC: 100.0/62.24/64.07 | MACRO-F1: 100.0/59.77/62.24 | node/edge ratio: 100.26/103.16%
# Avg Test Performance (5 runs):  | BACC: 66.01 ± 0.80 | MACRO-F1: 64.60 ± 0.92
# ================= Dataset [Cora] - StepIR [10] - ToBE [tobe1] =================
# Best Epoch:   81 | train/val/test | BACC: 100.0/69.67/68.66 | MACRO-F1: 100.0/67.24/66.88 | node/edge ratio: 100.26/101.44%
# Best Epoch:  175 | train/val/test | BACC: 100.0/71.16/70.44 | MACRO-F1: 100.0/69.88/69.15 | node/edge ratio: 100.26/101.67%
# Best Epoch:  263 | train/val/test | BACC: 100.0/75.20/73.91 | MACRO-F1: 100.0/72.38/72.18 | node/edge ratio: 100.26/101.49%
# Best Epoch:   71 | train/val/test | BACC: 100.0/69.50/67.75 | MACRO-F1: 100.0/68.11/66.80 | node/edge ratio: 100.26/101.55%
# Best Epoch:   77 | train/val/test | BACC: 100.0/78.03/77.92 | MACRO-F1: 100.0/75.06/76.42 | node/edge ratio: 100.26/101.60%
# Avg Test Performance (5 runs):  | BACC: 71.73 ± 1.67 | MACRO-F1: 70.29 ± 1.63
#
# ============================== Dataset [Citeseer] ==============================
# =============== Dataset [Citeseer] - StepIR [10] - ToBE [dummy] ===============
# Best Epoch:   57 | train/val/test | BACC: 100.0/42.27/41.85 | MACRO-F1: 100.0/33.57/32.96 | node/edge ratio: 100.00/100.00%
# Best Epoch:  211 | train/val/test | BACC: 100.0/46.49/44.47 | MACRO-F1: 100.0/39.83/37.62 | node/edge ratio: 100.00/100.00%
# Best Epoch:   85 | train/val/test | BACC: 100.0/35.72/36.41 | MACRO-F1: 100.0/28.07/27.64 | node/edge ratio: 100.00/100.00%
# Best Epoch:   66 | train/val/test | BACC: 100.0/36.54/36.79 | MACRO-F1: 100.0/28.47/26.82 | node/edge ratio: 100.00/100.00%
# Best Epoch:  171 | train/val/test | BACC: 100.0/34.90/32.80 | MACRO-F1: 100.0/22.77/21.23 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 38.46 ± 1.86 | MACRO-F1: 29.26 ± 2.50
# =============== Dataset [Citeseer] - StepIR [10] - ToBE [tobe0] ===============
# Best Epoch:  153 | train/val/test | BACC: 100.0/60.11/59.61 | MACRO-F1: 100.0/58.46/58.69 | node/edge ratio: 100.18/103.91%
# Best Epoch:  257 | train/val/test | BACC: 100.0/48.88/49.08 | MACRO-F1: 100.0/45.81/44.28 | node/edge ratio: 100.18/103.09%
# Best Epoch:  550 | train/val/test | BACC: 100.0/60.17/58.72 | MACRO-F1: 100.0/59.64/58.47 | node/edge ratio: 100.18/103.79%
# Best Epoch:  296 | train/val/test | BACC: 100.0/49.13/45.13 | MACRO-F1: 100.0/46.62/42.84 | node/edge ratio: 100.18/103.80%
# Best Epoch:   80 | train/val/test | BACC: 100.0/59.10/54.94 | MACRO-F1: 100.0/56.44/53.61 | node/edge ratio: 100.18/103.88%
# Avg Test Performance (5 runs):  | BACC: 53.50 ± 2.50 | MACRO-F1: 51.58 ± 3.04
# =============== Dataset [Citeseer] - StepIR [10] - ToBE [tobe1] ===============
# Best Epoch:  182 | train/val/test | BACC: 100.0/59.62/59.83 | MACRO-F1: 100.0/58.64/59.45 | node/edge ratio: 100.18/101.06%
# Best Epoch:   73 | train/val/test | BACC: 98.33/51.08/51.65 | MACRO-F1: 98.35/48.23/47.97 | node/edge ratio: 100.18/100.87%
# Best Epoch:  130 | train/val/test | BACC: 100.0/61.34/61.63 | MACRO-F1: 100.0/59.70/60.94 | node/edge ratio: 100.18/100.92%
# Best Epoch:  111 | train/val/test | BACC: 100.0/60.22/58.04 | MACRO-F1: 100.0/59.83/57.97 | node/edge ratio: 100.18/100.89%
# Best Epoch:  263 | train/val/test | BACC: 99.17/50.58/50.54 | MACRO-F1: 99.17/43.60/43.63 | node/edge ratio: 100.18/101.40%
# Avg Test Performance (5 runs):  | BACC: 56.34 ± 1.99 | MACRO-F1: 53.99 ± 3.08
#
# =============================== Dataset [Pubmed] ===============================
# ================ Dataset [Pubmed] - StepIR [10] - ToBE [dummy] ================
# Best Epoch:   60 | train/val/test | BACC: 100.0/64.17/61.63 | MACRO-F1: 100.0/50.42/48.98 | node/edge ratio: 100.00/100.00%
# Best Epoch:   67 | train/val/test | BACC: 100.0/71.01/69.15 | MACRO-F1: 100.0/64.89/64.67 | node/edge ratio: 100.00/100.00%
# Best Epoch:  100 | train/val/test | BACC: 100.0/66.70/64.53 | MACRO-F1: 100.0/55.09/53.49 | node/edge ratio: 100.00/100.00%
# Best Epoch:   95 | train/val/test | BACC: 100.0/75.37/69.35 | MACRO-F1: 100.0/68.57/61.28 | node/edge ratio: 100.00/100.00%
# Best Epoch:  291 | train/val/test | BACC: 100.0/63.73/60.01 | MACRO-F1: 100.0/48.47/45.26 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 64.93 ± 1.70 | MACRO-F1: 54.74 ± 3.26
# ================ Dataset [Pubmed] - StepIR [10] - ToBE [tobe0] ================
# Best Epoch:  174 | train/val/test | BACC: 100.0/71.96/67.36 | MACRO-F1: 100.0/72.12/67.90 | node/edge ratio: 100.02/103.22%
# Best Epoch:   64 | train/val/test | BACC: 98.33/71.54/67.70 | MACRO-F1: 92.48/69.74/66.00 | node/edge ratio: 100.02/103.11%
# Best Epoch:   90 | train/val/test | BACC: 98.33/74.52/68.92 | MACRO-F1: 92.48/74.63/68.84 | node/edge ratio: 100.02/103.06%
# Best Epoch:   95 | train/val/test | BACC: 100.0/69.31/64.68 | MACRO-F1: 100.0/67.46/62.45 | node/edge ratio: 100.02/103.12%
# Best Epoch:   93 | train/val/test | BACC: 100.0/73.90/68.14 | MACRO-F1: 100.0/73.33/67.61 | node/edge ratio: 100.02/103.36%
# Avg Test Performance (5 runs):  | BACC: 67.36 ± 0.64 | MACRO-F1: 66.56 ± 1.00
# ================ Dataset [Pubmed] - StepIR [10] - ToBE [tobe1] ================
# Best Epoch:   97 | train/val/test | BACC: 100.0/63.17/61.32 | MACRO-F1: 100.0/52.30/52.57 | node/edge ratio: 100.02/101.18%
# Best Epoch:  200 | train/val/test | BACC: 100.0/66.54/66.08 | MACRO-F1: 100.0/62.03/61.97 | node/edge ratio: 100.02/101.48%
# Best Epoch:  200 | train/val/test | BACC: 100.0/70.28/69.00 | MACRO-F1: 100.0/64.47/64.17 | node/edge ratio: 100.02/101.54%
# Best Epoch:   69 | train/val/test | BACC: 100.0/77.84/72.79 | MACRO-F1: 100.0/75.18/70.60 | node/edge ratio: 100.02/101.36%
# Best Epoch:   62 | train/val/test | BACC: 100.0/66.14/63.27 | MACRO-F1: 100.0/54.75/51.65 | node/edge ratio: 100.02/101.26%
# Avg Test Performance (5 runs):  | BACC: 66.49 ± 1.83 | MACRO-F1: 60.19 ± 3.22
#
# ////////////////////// Imbalance Type [Step] - Ratio [20] //////////////////////
#
# ================================ Dataset [Cora] ================================
# ================= Dataset [Cora] - StepIR [20] - ToBE [dummy] =================
# Best Epoch:  109 | train/val/test | BACC: 100.0/59.18/57.26 | MACRO-F1: 100.0/54.00/53.17 | node/edge ratio: 100.00/100.00%
# Best Epoch:   92 | train/val/test | BACC: 100.0/55.59/54.02 | MACRO-F1: 100.0/49.15/47.81 | node/edge ratio: 100.00/100.00%
# Best Epoch:  193 | train/val/test | BACC: 100.0/62.16/59.82 | MACRO-F1: 100.0/59.74/57.35 | node/edge ratio: 100.00/100.00%
# Best Epoch:   89 | train/val/test | BACC: 100.0/53.72/52.78 | MACRO-F1: 100.0/47.01/47.33 | node/edge ratio: 100.00/100.00%
# Best Epoch:   89 | train/val/test | BACC: 100.0/53.54/51.65 | MACRO-F1: 100.0/47.07/44.61 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 55.11 ± 1.35 | MACRO-F1: 50.05 ± 2.05
# ================= Dataset [Cora] - StepIR [20] - ToBE [tobe0] =================
# Best Epoch:  118 | train/val/test | BACC: 100.0/66.41/65.15 | MACRO-F1: 100.0/65.42/64.47 | node/edge ratio: 100.26/102.97%
# Best Epoch:  298 | train/val/test | BACC: 100.0/60.84/58.21 | MACRO-F1: 100.0/57.35/55.80 | node/edge ratio: 100.26/103.19%
# Best Epoch:  248 | train/val/test | BACC: 100.0/71.96/70.16 | MACRO-F1: 100.0/69.77/68.64 | node/edge ratio: 100.26/102.92%
# Best Epoch:  259 | train/val/test | BACC: 100.0/63.35/62.23 | MACRO-F1: 100.0/60.28/59.97 | node/edge ratio: 100.26/103.27%
# Best Epoch:  221 | train/val/test | BACC: 100.0/54.62/52.97 | MACRO-F1: 100.0/51.31/49.77 | node/edge ratio: 100.26/103.42%
# Avg Test Performance (5 runs):  | BACC: 61.74 ± 2.62 | MACRO-F1: 59.73 ± 2.94
# ================= Dataset [Cora] - StepIR [20] - ToBE [tobe1] =================
# Best Epoch:  167 | train/val/test | BACC: 100.0/68.23/67.67 | MACRO-F1: 100.0/65.53/65.32 | node/edge ratio: 100.26/101.44%
# Best Epoch:  195 | train/val/test | BACC: 100.0/74.49/71.32 | MACRO-F1: 100.0/71.38/69.76 | node/edge ratio: 100.26/101.58%
# Best Epoch:  164 | train/val/test | BACC: 100.0/74.54/72.44 | MACRO-F1: 100.0/71.58/70.76 | node/edge ratio: 100.26/101.63%
# Best Epoch:  259 | train/val/test | BACC: 100.0/67.73/67.33 | MACRO-F1: 100.0/65.64/65.73 | node/edge ratio: 100.26/101.53%
# Best Epoch:   94 | train/val/test | BACC: 100.0/63.67/61.72 | MACRO-F1: 100.0/58.09/57.33 | node/edge ratio: 100.26/101.61%
# Avg Test Performance (5 runs):  | BACC: 68.09 ± 1.68 | MACRO-F1: 65.78 ± 2.12
#
# ============================== Dataset [Citeseer] ==============================
# =============== Dataset [Citeseer] - StepIR [20] - ToBE [dummy] ===============
# Best Epoch:  146 | train/val/test | BACC: 100.0/35.57/34.08 | MACRO-F1: 100.0/25.16/23.58 | node/edge ratio: 100.00/100.00%
# Best Epoch:  188 | train/val/test | BACC: 100.0/37.44/35.35 | MACRO-F1: 100.0/29.69/26.51 | node/edge ratio: 100.00/100.00%
# Best Epoch:  145 | train/val/test | BACC: 100.0/33.93/32.20 | MACRO-F1: 100.0/22.69/20.89 | node/edge ratio: 100.00/100.00%
# Best Epoch:   14 | train/val/test | BACC: 46.67/35.14/34.59 | MACRO-F1: 45.51/21.72/21.35 | node/edge ratio: 100.00/100.00%
# Best Epoch:   16 | train/val/test | BACC: 46.67/34.95/35.07 | MACRO-F1: 45.50/22.01/21.49 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 34.26 ± 0.50 | MACRO-F1: 22.76 ± 0.93
# =============== Dataset [Citeseer] - StepIR [20] - ToBE [tobe0] ===============
# Best Epoch:  250 | train/val/test | BACC: 100.0/46.73/46.74 | MACRO-F1: 100.0/44.42/42.49 | node/edge ratio: 100.18/104.90%
# Best Epoch:  284 | train/val/test | BACC: 100.0/49.53/47.41 | MACRO-F1: 100.0/46.94/44.77 | node/edge ratio: 100.18/104.22%
# Best Epoch:  194 | train/val/test | BACC: 100.0/59.21/61.31 | MACRO-F1: 100.0/57.92/60.51 | node/edge ratio: 100.18/104.92%
# Best Epoch:  241 | train/val/test | BACC: 100.0/47.59/43.71 | MACRO-F1: 100.0/46.50/42.67 | node/edge ratio: 100.18/104.02%
# Best Epoch:  163 | train/val/test | BACC: 98.33/44.16/45.28 | MACRO-F1: 98.35/41.46/42.92 | node/edge ratio: 100.18/104.39%
# Avg Test Performance (5 runs):  | BACC: 48.89 ± 2.84 | MACRO-F1: 46.67 ± 3.12
# =============== Dataset [Citeseer] - StepIR [20] - ToBE [tobe1] ===============
# Best Epoch:  121 | train/val/test | BACC: 100.0/60.13/59.02 | MACRO-F1: 100.0/59.45/58.80 | node/edge ratio: 100.18/101.20%
# Best Epoch:  592 | train/val/test | BACC: 100.0/54.80/55.24 | MACRO-F1: 100.0/53.81/55.04 | node/edge ratio: 100.18/101.28%
# Best Epoch:  291 | train/val/test | BACC: 100.0/53.53/55.21 | MACRO-F1: 100.0/52.45/54.84 | node/edge ratio: 100.18/101.07%
# Best Epoch:  245 | train/val/test | BACC: 100.0/57.20/55.70 | MACRO-F1: 100.0/57.20/55.95 | node/edge ratio: 100.18/100.94%
# Best Epoch:  106 | train/val/test | BACC: 100.0/45.52/42.88 | MACRO-F1: 100.0/35.30/33.46 | node/edge ratio: 100.18/101.42%
# Avg Test Performance (5 runs):  | BACC: 53.61 ± 2.48 | MACRO-F1: 51.62 ± 4.11
#
# =============================== Dataset [Pubmed] ===============================
# ================ Dataset [Pubmed] - StepIR [20] - ToBE [dummy] ================
# Best Epoch:   99 | train/val/test | BACC: 100.0/62.88/59.69 | MACRO-F1: 100.0/48.95/46.62 | node/edge ratio: 100.00/100.00%
# Best Epoch:  123 | train/val/test | BACC: 100.0/66.61/62.61 | MACRO-F1: 100.0/55.53/52.73 | node/edge ratio: 100.00/100.00%
# Best Epoch:  147 | train/val/test | BACC: 100.0/64.69/61.75 | MACRO-F1: 100.0/50.67/48.59 | node/edge ratio: 100.00/100.00%
# Best Epoch:  196 | train/val/test | BACC: 100.0/64.05/60.62 | MACRO-F1: 100.0/48.82/45.61 | node/edge ratio: 100.00/100.00%
# Best Epoch:  214 | train/val/test | BACC: 100.0/63.75/60.38 | MACRO-F1: 100.0/48.04/45.23 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 61.01 ± 0.46 | MACRO-F1: 47.76 ± 1.23
# ================ Dataset [Pubmed] - StepIR [20] - ToBE [tobe0] ================
# Best Epoch:  158 | train/val/test | BACC: 100.0/70.21/68.81 | MACRO-F1: 100.0/66.47/65.83 | node/edge ratio: 100.02/103.54%
# Best Epoch:  332 | train/val/test | BACC: 100.0/72.07/68.34 | MACRO-F1: 100.0/70.63/67.66 | node/edge ratio: 100.02/103.56%
# Best Epoch:    7 | train/val/test | BACC: 65.00/61.04/57.89 | MACRO-F1: 64.22/47.16/44.86 | node/edge ratio: 100.02/104.14%
# Best Epoch:  155 | train/val/test | BACC: 100.0/67.28/63.89 | MACRO-F1: 100.0/61.29/58.09 | node/edge ratio: 100.02/103.56%
# Best Epoch:  114 | train/val/test | BACC: 100.0/67.80/65.35 | MACRO-F1: 100.0/66.61/64.27 | node/edge ratio: 100.02/103.40%
# Avg Test Performance (5 runs):  | BACC: 64.86 ± 1.76 | MACRO-F1: 60.14 ± 3.71
# ================ Dataset [Pubmed] - StepIR [20] - ToBE [tobe1] ================
# Best Epoch:   64 | train/val/test | BACC: 98.33/68.56/66.39 | MACRO-F1: 88.03/65.39/64.83 | node/edge ratio: 100.02/101.19%
# Best Epoch:   81 | train/val/test | BACC: 98.33/68.41/66.78 | MACRO-F1: 88.03/64.01/63.01 | node/edge ratio: 100.02/101.30%
# Best Epoch:   77 | train/val/test | BACC: 100.0/72.61/70.93 | MACRO-F1: 100.0/65.54/64.57 | node/edge ratio: 100.02/101.32%
# Best Epoch:  479 | train/val/test | BACC: 100.0/76.43/70.40 | MACRO-F1: 100.0/72.58/66.67 | node/edge ratio: 100.02/101.42%
# Best Epoch:   95 | train/val/test | BACC: 100.0/65.36/63.34 | MACRO-F1: 100.0/52.85/49.91 | node/edge ratio: 100.02/101.14%
# Avg Test Performance (5 runs):  | BACC: 67.57 ± 1.25 | MACRO-F1: 61.80 ± 2.71
#
# //////////////////// Imbalance Type [Natural] - Ratio [50] ////////////////////
#
# ================================ Dataset [Cora] ================================
# ================ Dataset [Cora] - NaturalIR [50] - ToBE [dummy] ================
# Best Epoch:  179 | train/val/test | BACC: 100.0/58.59/55.43 | MACRO-F1: 100.0/56.60/52.78 | node/edge ratio: 100.00/100.00%
# Best Epoch:  276 | train/val/test | BACC: 100.0/70.38/68.89 | MACRO-F1: 100.0/70.49/69.38 | node/edge ratio: 100.00/100.00%
# Best Epoch:   68 | train/val/test | BACC: 85.71/50.84/49.72 | MACRO-F1: 80.95/48.90/47.37 | node/edge ratio: 100.00/100.00%
# Best Epoch:  267 | train/val/test | BACC: 100.0/62.26/63.83 | MACRO-F1: 100.0/62.04/63.71 | node/edge ratio: 100.00/100.00%
# Best Epoch:  119 | train/val/test | BACC: 100.0/60.33/62.38 | MACRO-F1: 100.0/59.47/60.70 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 60.05 ± 3.01 | MACRO-F1: 58.79 ± 3.50
# ================ Dataset [Cora] - NaturalIR [50] - ToBE [tobe0] ================
# Best Epoch:  259 | train/val/test | BACC: 100.0/72.25/70.25 | MACRO-F1: 100.0/70.96/69.21 | node/edge ratio: 100.26/101.71%
# Best Epoch:  275 | train/val/test | BACC: 100.0/64.17/61.71 | MACRO-F1: 100.0/62.81/60.94 | node/edge ratio: 100.26/101.45%
# Best Epoch:  279 | train/val/test | BACC: 100.0/59.92/57.51 | MACRO-F1: 100.0/58.53/56.23 | node/edge ratio: 100.26/101.83%
# Best Epoch:  183 | train/val/test | BACC: 100.0/64.86/66.21 | MACRO-F1: 100.0/61.94/62.95 | node/edge ratio: 100.26/101.72%
# Best Epoch:  466 | train/val/test | BACC: 100.0/72.16/70.98 | MACRO-F1: 100.0/71.09/70.17 | node/edge ratio: 100.26/101.58%
# Avg Test Performance (5 runs):  | BACC: 65.33 ± 2.29 | MACRO-F1: 63.90 ± 2.33
# ================ Dataset [Cora] - NaturalIR [50] - ToBE [tobe1] ================
# Best Epoch:  104 | train/val/test | BACC: 100.0/64.72/63.49 | MACRO-F1: 100.0/61.62/60.45 | node/edge ratio: 100.26/101.07%
# Best Epoch:  296 | train/val/test | BACC: 100.0/71.46/68.28 | MACRO-F1: 100.0/70.73/68.24 | node/edge ratio: 100.26/100.77%
# Best Epoch:  106 | train/val/test | BACC: 100.0/59.89/59.74 | MACRO-F1: 100.0/55.75/55.94 | node/edge ratio: 100.26/101.34%
# Best Epoch:  220 | train/val/test | BACC: 100.0/68.37/67.28 | MACRO-F1: 100.0/65.70/64.16 | node/edge ratio: 100.26/101.08%
# Best Epoch:  121 | train/val/test | BACC: 100.0/66.90/65.74 | MACRO-F1: 100.0/63.85/62.71 | node/edge ratio: 100.26/100.94%
# Avg Test Performance (5 runs):  | BACC: 64.91 ± 1.36 | MACRO-F1: 62.30 ± 1.82
#
# ============================== Dataset [Citeseer] ==============================
# ============== Dataset [Citeseer] - NaturalIR [50] - ToBE [dummy] ==============
# Best Epoch:   90 | train/val/test | BACC: 83.33/48.05/49.31 | MACRO-F1: 81.48/40.93/42.39 | node/edge ratio: 100.00/100.00%
# Best Epoch:  202 | train/val/test | BACC: 100.0/51.78/50.41 | MACRO-F1: 100.0/46.60/45.46 | node/edge ratio: 100.00/100.00%
# Best Epoch:  266 | train/val/test | BACC: 100.0/45.75/44.86 | MACRO-F1: 100.0/39.30/38.70 | node/edge ratio: 100.00/100.00%
# Best Epoch:  175 | train/val/test | BACC: 100.0/46.81/48.28 | MACRO-F1: 100.0/40.47/42.41 | node/edge ratio: 100.00/100.00%
# Best Epoch:  146 | train/val/test | BACC: 100.0/42.20/42.61 | MACRO-F1: 100.0/32.24/32.50 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 47.09 ± 1.30 | MACRO-F1: 40.29 ± 1.99
# ============== Dataset [Citeseer] - NaturalIR [50] - ToBE [tobe0] ==============
# Best Epoch:  209 | train/val/test | BACC: 100.0/55.69/52.59 | MACRO-F1: 100.0/54.93/52.27 | node/edge ratio: 100.18/101.81%
# Best Epoch:  546 | train/val/test | BACC: 100.0/50.28/48.10 | MACRO-F1: 100.0/50.09/47.81 | node/edge ratio: 100.18/101.66%
# Best Epoch:  364 | train/val/test | BACC: 100.0/55.58/54.55 | MACRO-F1: 100.0/54.95/53.71 | node/edge ratio: 100.18/102.09%
# Best Epoch:   90 | train/val/test | BACC: 100.0/53.28/52.17 | MACRO-F1: 100.0/52.00/51.01 | node/edge ratio: 100.18/101.93%
# Best Epoch:  251 | train/val/test | BACC: 100.0/57.22/57.65 | MACRO-F1: 100.0/55.72/55.98 | node/edge ratio: 100.18/102.00%
# Avg Test Performance (5 runs):  | BACC: 53.01 ± 1.40 | MACRO-F1: 52.15 ± 1.22
# ============== Dataset [Citeseer] - NaturalIR [50] - ToBE [tobe1] ==============
# Best Epoch:  125 | train/val/test | BACC: 100.0/61.04/59.02 | MACRO-F1: 100.0/60.26/58.01 | node/edge ratio: 100.18/100.43%
# Best Epoch:  260 | train/val/test | BACC: 100.0/53.64/50.39 | MACRO-F1: 100.0/52.99/49.52 | node/edge ratio: 100.18/100.47%
# Best Epoch:  126 | train/val/test | BACC: 100.0/60.06/60.31 | MACRO-F1: 100.0/58.12/58.61 | node/edge ratio: 100.18/100.53%
# Best Epoch:  177 | train/val/test | BACC: 100.0/54.97/54.34 | MACRO-F1: 100.0/53.60/52.80 | node/edge ratio: 100.18/100.53%
# Best Epoch:  293 | train/val/test | BACC: 100.0/61.41/61.13 | MACRO-F1: 100.0/59.10/58.51 | node/edge ratio: 100.18/100.50%
# Avg Test Performance (5 runs):  | BACC: 57.04 ± 1.82 | MACRO-F1: 55.49 ± 1.65
#
# =============================== Dataset [Pubmed] ===============================
# =============== Dataset [Pubmed] - NaturalIR [50] - ToBE [dummy] ===============
# Best Epoch:  177 | train/val/test | BACC: 100.0/51.86/51.51 | MACRO-F1: 100.0/46.41/46.08 | node/edge ratio: 100.00/100.00%
# Best Epoch:  193 | train/val/test | BACC: 100.0/49.04/49.97 | MACRO-F1: 100.0/44.82/45.80 | node/edge ratio: 100.00/100.00%
# Best Epoch:  170 | train/val/test | BACC: 100.0/47.46/47.64 | MACRO-F1: 100.0/44.33/44.54 | node/edge ratio: 100.00/100.00%
# Best Epoch:   85 | train/val/test | BACC: 65.33/55.62/55.56 | MACRO-F1: 60.10/49.24/49.20 | node/edge ratio: 100.00/100.00%
# Best Epoch:  188 | train/val/test | BACC: 100.0/53.13/53.01 | MACRO-F1: 100.0/47.68/47.61 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 51.54 ± 1.20 | MACRO-F1: 46.65 ± 0.72
# =============== Dataset [Pubmed] - NaturalIR [50] - ToBE [tobe0] ===============
# Best Epoch:  156 | train/val/test | BACC: 66.67/54.71/54.54 | MACRO-F1: 64.44/50.72/50.66 | node/edge ratio: 100.02/102.35%
# Best Epoch:  211 | train/val/test | BACC: 100.0/41.38/41.87 | MACRO-F1: 100.0/35.33/35.92 | node/edge ratio: 100.02/101.31%
# Best Epoch:   69 | train/val/test | BACC: 60.67/54.00/53.51 | MACRO-F1: 49.48/47.95/47.47 | node/edge ratio: 100.02/102.36%
# Best Epoch:  106 | train/val/test | BACC: 97.33/58.42/58.64 | MACRO-F1: 91.20/55.48/55.96 | node/edge ratio: 100.02/102.01%
# Best Epoch:  169 | train/val/test | BACC: 66.67/54.68/54.43 | MACRO-F1: 66.34/48.31/48.09 | node/edge ratio: 100.02/102.20%
# Avg Test Performance (5 runs):  | BACC: 52.60 ± 2.53 | MACRO-F1: 47.62 ± 2.94
# =============== Dataset [Pubmed] - NaturalIR [50] - ToBE [tobe1] ===============
# Best Epoch:  180 | train/val/test | BACC: 94.00/54.61/54.24 | MACRO-F1: 83.66/49.05/48.63 | node/edge ratio: 100.02/100.57%
# Best Epoch:  113 | train/val/test | BACC: 100.0/40.22/40.80 | MACRO-F1: 100.0/33.30/33.99 | node/edge ratio: 100.02/100.27%
# Best Epoch:  153 | train/val/test | BACC: 100.0/53.67/53.29 | MACRO-F1: 100.0/52.43/51.75 | node/edge ratio: 100.02/100.51%
# Best Epoch:  161 | train/val/test | BACC: 97.33/57.66/57.47 | MACRO-F1: 91.20/54.53/54.05 | node/edge ratio: 100.02/100.51%
# Best Epoch:  210 | train/val/test | BACC: 100.0/74.26/73.94 | MACRO-F1: 100.0/75.16/74.77 | node/edge ratio: 100.02/100.91%
# Avg Test Performance (5 runs):  | BACC: 55.95 ± 4.76 | MACRO-F1: 52.64 ± 5.85
#
# //////////////////// Imbalance Type [Natural] - Ratio [100] ////////////////////
#
# ================================ Dataset [Cora] ================================
# =============== Dataset [Cora] - NaturalIR [100] - ToBE [dummy] ===============
# Best Epoch:  101 | train/val/test | BACC: 85.71/61.94/60.90 | MACRO-F1: 84.13/60.55/59.84 | node/edge ratio: 100.00/100.00%
# Best Epoch:  245 | train/val/test | BACC: 100.0/70.65/66.15 | MACRO-F1: 100.0/70.49/66.56 | node/edge ratio: 100.00/100.00%
# Best Epoch:  177 | train/val/test | BACC: 99.69/50.73/50.48 | MACRO-F1: 99.77/48.05/47.59 | node/edge ratio: 100.00/100.00%
# Best Epoch:  246 | train/val/test | BACC: 99.69/58.30/59.41 | MACRO-F1: 99.77/57.30/58.63 | node/edge ratio: 100.00/100.00%
# Best Epoch:  332 | train/val/test | BACC: 100.0/63.68/64.41 | MACRO-F1: 100.0/65.72/65.00 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 60.27 ± 2.44 | MACRO-F1: 59.52 ± 2.99
# =============== Dataset [Cora] - NaturalIR [100] - ToBE [tobe0] ===============
# Best Epoch:  286 | train/val/test | BACC: 100.0/67.09/65.21 | MACRO-F1: 100.0/67.26/65.71 | node/edge ratio: 100.26/101.69%
# Best Epoch:  144 | train/val/test | BACC: 85.40/70.08/64.80 | MACRO-F1: 82.63/68.38/63.06 | node/edge ratio: 100.26/101.51%
# Best Epoch:  234 | train/val/test | BACC: 100.0/61.81/60.18 | MACRO-F1: 100.0/61.72/59.56 | node/edge ratio: 100.26/102.14%
# Best Epoch:  219 | train/val/test | BACC: 99.69/63.67/63.79 | MACRO-F1: 99.77/61.84/61.81 | node/edge ratio: 100.26/101.73%
# Best Epoch:  375 | train/val/test | BACC: 100.0/68.83/69.68 | MACRO-F1: 100.0/69.12/69.64 | node/edge ratio: 100.26/101.83%
# Avg Test Performance (5 runs):  | BACC: 64.73 ± 1.36 | MACRO-F1: 63.96 ± 1.55
# =============== Dataset [Cora] - NaturalIR [100] - ToBE [tobe1] ===============
# Best Epoch:  167 | train/val/test | BACC: 100.0/68.24/66.00 | MACRO-F1: 100.0/66.44/63.93 | node/edge ratio: 100.26/101.24%
# Best Epoch:  191 | train/val/test | BACC: 100.0/74.60/71.14 | MACRO-F1: 100.0/73.87/70.85 | node/edge ratio: 100.26/100.89%
# Best Epoch:  217 | train/val/test | BACC: 100.0/65.46/65.91 | MACRO-F1: 100.0/65.80/66.29 | node/edge ratio: 100.26/101.44%
# Best Epoch:  206 | train/val/test | BACC: 99.55/65.59/65.74 | MACRO-F1: 99.37/64.03/63.83 | node/edge ratio: 100.26/101.11%
# Best Epoch:  246 | train/val/test | BACC: 100.0/74.08/73.31 | MACRO-F1: 100.0/75.00/73.72 | node/edge ratio: 100.26/101.30%
# Avg Test Performance (5 runs):  | BACC: 68.42 ± 1.42 | MACRO-F1: 67.72 ± 1.76
#
# ============================== Dataset [Citeseer] ==============================
# ============= Dataset [Citeseer] - NaturalIR [100] - ToBE [dummy] =============
# Best Epoch:  305 | train/val/test | BACC: 100.0/45.25/45.35 | MACRO-F1: 100.0/37.98/38.12 | node/edge ratio: 100.00/100.00%
# Best Epoch:  188 | train/val/test | BACC: 91.33/46.95/46.65 | MACRO-F1: 93.02/42.01/41.44 | node/edge ratio: 100.00/100.00%
# Best Epoch:  239 | train/val/test | BACC: 100.0/45.08/44.45 | MACRO-F1: 100.0/38.78/37.72 | node/edge ratio: 100.00/100.00%
# Best Epoch:  186 | train/val/test | BACC: 83.17/46.01/47.04 | MACRO-F1: 79.71/38.90/39.77 | node/edge ratio: 100.00/100.00%
# Best Epoch:   85 | train/val/test | BACC: 74.83/42.53/42.20 | MACRO-F1: 76.12/33.65/32.77 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 45.14 ± 0.78 | MACRO-F1: 37.97 ± 1.30
# ============= Dataset [Citeseer] - NaturalIR [100] - ToBE [tobe0] =============
# Best Epoch:  354 | train/val/test | BACC: 83.17/53.29/52.28 | MACRO-F1: 79.71/51.43/50.74 | node/edge ratio: 100.18/101.90%
# Best Epoch:  144 | train/val/test | BACC: 83.17/50.61/49.25 | MACRO-F1: 82.00/47.13/45.84 | node/edge ratio: 100.18/103.07%
# Best Epoch:  296 | train/val/test | BACC: 100.0/57.63/56.55 | MACRO-F1: 100.0/56.64/55.65 | node/edge ratio: 100.18/102.64%
# Best Epoch:  358 | train/val/test | BACC: 100.0/55.48/55.39 | MACRO-F1: 100.0/54.29/54.11 | node/edge ratio: 100.18/102.39%
# Best Epoch:  274 | train/val/test | BACC: 99.67/55.49/56.34 | MACRO-F1: 94.07/52.79/53.50 | node/edge ratio: 100.18/103.43%
# Avg Test Performance (5 runs):  | BACC: 53.96 ± 1.26 | MACRO-F1: 51.97 ± 1.54
# ============= Dataset [Citeseer] - NaturalIR [100] - ToBE [tobe1] =============
# Best Epoch:  350 | train/val/test | BACC: 99.15/59.33/59.38 | MACRO-F1: 99.40/58.11/58.39 | node/edge ratio: 100.18/100.45%
# Best Epoch:  230 | train/val/test | BACC: 99.83/56.85/56.78 | MACRO-F1: 99.71/55.94/55.74 | node/edge ratio: 100.18/100.74%
# Best Epoch:  303 | train/val/test | BACC: 100.0/56.23/57.84 | MACRO-F1: 100.0/53.84/55.62 | node/edge ratio: 100.18/100.56%
# Best Epoch:  449 | train/val/test | BACC: 99.83/60.08/60.70 | MACRO-F1: 99.71/58.56/58.95 | node/edge ratio: 100.18/100.58%
# Best Epoch:  252 | train/val/test | BACC: 99.67/51.33/52.59 | MACRO-F1: 94.07/45.37/46.49 | node/edge ratio: 100.18/100.73%
# Avg Test Performance (5 runs):  | BACC: 57.46 ± 1.24 | MACRO-F1: 55.04 ± 2.00
#
# =============================== Dataset [Pubmed] ===============================
# ============== Dataset [Pubmed] - NaturalIR [100] - ToBE [dummy] ==============
# Best Epoch:  168 | train/val/test | BACC: 66.67/53.47/53.59 | MACRO-F1: 65.08/47.11/47.23 | node/edge ratio: 100.00/100.00%
# Best Epoch:  161 | train/val/test | BACC: 100.0/45.32/46.29 | MACRO-F1: 100.0/39.01/39.99 | node/edge ratio: 100.00/100.00%
# Best Epoch:   88 | train/val/test | BACC: 66.67/48.35/48.26 | MACRO-F1: 65.08/42.04/41.97 | node/edge ratio: 100.00/100.00%
# Best Epoch:   95 | train/val/test | BACC: 66.67/51.23/51.28 | MACRO-F1: 65.08/45.35/45.38 | node/edge ratio: 100.00/100.00%
# Best Epoch:  102 | train/val/test | BACC: 66.67/51.96/51.58 | MACRO-F1: 65.08/46.06/45.71 | node/edge ratio: 100.00/100.00%
# Avg Test Performance (5 runs):  | BACC: 50.20 ± 1.16 | MACRO-F1: 44.06 ± 1.19
# ============== Dataset [Pubmed] - NaturalIR [100] - ToBE [tobe0] ==============
# Best Epoch:  279 | train/val/test | BACC: 100.0/56.41/56.36 | MACRO-F1: 100.0/51.43/51.34 | node/edge ratio: 100.02/102.32%
# Best Epoch:  129 | train/val/test | BACC: 66.67/44.74/45.60 | MACRO-F1: 65.08/38.09/39.05 | node/edge ratio: 100.02/101.89%
# Best Epoch:  334 | train/val/test | BACC: 100.0/57.03/56.80 | MACRO-F1: 100.0/56.27/56.03 | node/edge ratio: 100.02/102.22%
# Best Epoch:  180 | train/val/test | BACC: 100.0/45.41/45.02 | MACRO-F1: 100.0/40.42/39.70 | node/edge ratio: 100.02/102.16%
# Best Epoch:   67 | train/val/test | BACC: 66.33/55.30/55.02 | MACRO-F1: 64.75/48.93/48.69 | node/edge ratio: 100.02/102.40%
# Avg Test Performance (5 runs):  | BACC: 51.76 ± 2.37 | MACRO-F1: 46.96 ± 2.96
# ============== Dataset [Pubmed] - NaturalIR [100] - ToBE [tobe1] ==============
# Best Epoch:  155 | train/val/test | BACC: 65.67/56.81/56.70 | MACRO-F1: 60.60/50.16/50.06 | node/edge ratio: 100.02/100.80%
# Best Epoch:  159 | train/val/test | BACC: 100.0/47.90/48.16 | MACRO-F1: 100.0/43.07/43.23 | node/edge ratio: 100.02/100.33%
# Best Epoch:  162 | train/val/test | BACC: 64.67/57.01/57.27 | MACRO-F1: 56.99/50.39/50.62 | node/edge ratio: 100.02/100.57%
# Best Epoch:   89 | train/val/test | BACC: 66.00/55.34/54.99 | MACRO-F1: 61.98/49.09/48.80 | node/edge ratio: 100.02/100.55%
# Best Epoch:  212 | train/val/test | BACC: 66.67/55.84/55.50 | MACRO-F1: 66.50/49.37/49.08 | node/edge ratio: 100.02/100.76%
# Avg Test Performance (5 runs):  | BACC: 54.52 ± 1.47 | MACRO-F1: 48.36 ± 1.18
